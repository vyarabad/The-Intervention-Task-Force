# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os

# %%
df = pd.read_csv("../data/west_virginia_opioid_data.csv", dtype={"FIPS_Code": str})
df
# Out:
#      Year FIPS_Code          State    County  Labor_Force_Participation_Rate  \
# 0    2023     54001  West Virginia   Barbour                            50.0
# 1    2023     54003  West Virginia  Berkeley                            66.7
# 2    2023     54005  West Virginia     Boone                            44.4
# 3    2023     54007  West Virginia   Braxton                            42.1
# 4    2023     54009  West Virginia    Brooke                            54.6
# ..    ...       ...            ...       ...                             ...
# 600  2013     54101  West Virginia   Webster                            47.2
# 601  2013     54103  West Virginia    Wetzel                            45.3
# 602  2013     54105  West Virginia      Wirt                            53.1
# 603  2013     54107  West Virginia      Wood                            58.5
# 604  2013     54109  West Virginia   Wyoming                            38.3
#
#      Unemployment_Rate  Median_Household_Income  Poverty_Percent_All_Ages  \
# 0                 10.3                    48347                      20.8
# 1                  4.8                    77329                      11.4
# 2                  8.8                    56152                      17.3
# 3                 12.8                    44449                      18.8
# 4                  6.0                    52116                      12.1
# ..                 ...                      ...                       ...
# 600               13.9                    27645                      25.2
# 601                8.5                    37969                      19.7
# 602               17.1                    34702                      19.3
# 603                9.8                    42287                      16.2
# 604                6.5                    34454                      21.5
#
#      Poverty_Percent_Age_0_17  Pct_Never_Married  Pct_Divorced  \
# 0                        29.1               45.8          10.3
# 1                        14.2               48.9           5.3
# 2                        20.8               49.3           8.9
# 3                        21.7               48.2           8.6
# 4                        17.1               44.1          11.0
# ..                        ...                ...           ...
# 600                      26.7               57.2           7.8
# 601                      26.2               54.3           8.4
# 602                      25.8               57.3           6.8
# 603                      23.7               53.3           7.7
# 604                      33.4               56.2           8.8
#
#      Pct_Less_Than_HS  Pct_HS_Grad  Pct_Bachelors_Plus  \
# 0                 8.0         53.4                12.2
# 1                 6.5         36.9                24.3
# 2                10.1         46.8                11.9
# 3                10.6         51.1                11.9
# 4                 5.5         41.5                21.9
# ..                ...          ...                 ...
# 600              22.0         44.7                 5.8
# 601              14.9         47.6                10.3
# 602               7.4         51.0                 9.4
# 603               7.6         38.1                19.0
# 604              16.3         47.9                 6.4
#
#      Rural_Urban_Continuum_Code  LA_Opioid_Rate  LA_Tot_Opioid_Clms
# 0                           9.0            5.41               155.0
# 1                           2.0            8.92               997.0
# 2                           3.0            1.62               114.0
# 3                           8.0            4.30                70.0
# 4                           3.0            1.72                22.0
# ..                          ...             ...                 ...
# 600                         9.0            4.09               114.0
# 601                         6.0            4.06               135.0
# 602                         3.0             NaN                 NaN
# 603                         3.0           10.65              5330.0
# 604                         6.0            0.73               106.0
#
# [605 rows x 17 columns]

# %%
print("Missing values BEFORE interpolation:")
print(df.isnull().sum())
print(f"\nTotal missing: {df.isnull().sum().sum()}")
# Out:
# Missing values BEFORE interpolation:
# Year                               0
# FIPS_Code                          0
# State                              0
# County                             0
# Labor_Force_Participation_Rate     0
# Unemployment_Rate                  0
# Median_Household_Income            0
# Poverty_Percent_All_Ages           0
# Poverty_Percent_Age_0_17           0
# Pct_Never_Married                  0
# Pct_Divorced                       0
# Pct_Less_Than_HS                   0
# Pct_HS_Grad                        0
# Pct_Bachelors_Plus                 0
# Rural_Urban_Continuum_Code         0
# LA_Opioid_Rate                    30
# LA_Tot_Opioid_Clms                30
# dtype: int64
#
# Total missing: 60

# %%
df = df.sort_values(["FIPS_Code", "Year"]).reset_index(drop=True)

# %%
cols_to_interpolate = ["LA_Opioid_Rate", "LA_Tot_Opioid_Clms"]

# %%
df[cols_to_interpolate] = (
    df.groupby("FIPS_Code")[cols_to_interpolate]
    .transform(lambda group: group.interpolate(method="linear", limit_direction="both"))
)

# %%
print("\nMissing values AFTER interpolation:")
print(df.isnull().sum())
print(f"\nTotal missing: {df.isnull().sum().sum()}")
# Out:
# Missing values AFTER interpolation:
# Year                              0
# FIPS_Code                         0
# State                             0
# County                            0
# Labor_Force_Participation_Rate    0
# Unemployment_Rate                 0
# Median_Household_Income           0
# Poverty_Percent_All_Ages          0
# Poverty_Percent_Age_0_17          0
# Pct_Never_Married                 0
# Pct_Divorced                      0
# Pct_Less_Than_HS                  0
# Pct_HS_Grad                       0
# Pct_Bachelors_Plus                0
# Rural_Urban_Continuum_Code        0
# LA_Opioid_Rate                    0
# LA_Tot_Opioid_Clms                0
# dtype: int64
#
# Total missing: 0

# %%
df
# Out:
#      Year FIPS_Code          State   County  Labor_Force_Participation_Rate  \
# 0    2013     54001  West Virginia  Barbour                            51.8
# 1    2014     54001  West Virginia  Barbour                            49.7
# 2    2015     54001  West Virginia  Barbour                            51.2
# 3    2016     54001  West Virginia  Barbour                            51.5
# 4    2017     54001  West Virginia  Barbour                            51.1
# ..    ...       ...            ...      ...                             ...
# 600  2019     54109  West Virginia  Wyoming                            39.9
# 601  2020     54109  West Virginia  Wyoming                            41.0
# 602  2021     54109  West Virginia  Wyoming                            36.9
# 603  2022     54109  West Virginia  Wyoming                            37.3
# 604  2023     54109  West Virginia  Wyoming                            38.5
#
#      Unemployment_Rate  Median_Household_Income  Poverty_Percent_All_Ages  \
# 0                  8.0                    37327                      17.6
# 1                  8.9                    36351                      19.8
# 2                  9.0                    37066                      21.5
# 3                  7.9                    36733                      22.4
# 4                  8.9                    37516                      22.5
# ..                 ...                      ...                       ...
# 600               13.4                    42332                      22.4
# 601               11.6                    44095                      21.4
# 602                8.0                    44630                      25.3
# 603                6.4                    44510                      24.4
# 604                5.6                    48038                      22.6
#
#      Poverty_Percent_Age_0_17  Pct_Never_Married  Pct_Divorced  \
# 0                        28.7               55.1           7.4
# 1                        29.1               53.5           7.7
# 2                        30.3               52.0           7.4
# 3                        32.5               51.1           7.1
# 4                        32.5               49.6           7.6
# ..                        ...                ...           ...
# 600                      29.4               59.7           8.4
# 601                      29.8               62.6           7.7
# 602                      31.2               55.8           8.0
# 603                      31.3               51.7           9.4
# 604                      26.0               55.2           9.2
#
#      Pct_Less_Than_HS  Pct_HS_Grad  Pct_Bachelors_Plus  \
# 0                14.6         46.1                11.7
# 1                12.8         48.2                12.2
# 2                12.7         47.1                11.9
# 3                13.2         43.9                12.8
# 4                12.1         44.5                15.3
# ..                ...          ...                 ...
# 600              11.4         48.7                 9.3
# 601              13.5         46.6                11.8
# 602              14.0         46.7                11.6
# 603              15.8         46.6                11.4
# 604              15.0         45.7                12.0
#
#      Rural_Urban_Continuum_Code  LA_Opioid_Rate  LA_Tot_Opioid_Clms
# 0                           6.0            5.85               253.0
# 1                           6.0           10.56               649.0
# 2                           6.0           10.95               565.0
# 3                           6.0            7.85               352.0
# 4                           6.0            7.47               320.0
# ..                          ...             ...                 ...
# 600                         6.0            0.39                23.5
# 601                         6.0            0.36                17.0
# 602                         6.0            0.51                24.0
# 603                         6.0            0.94                41.0
# 604                         8.0            1.39                56.0
#
# [605 rows x 17 columns]

# %%
df.to_csv("../data/west_virginia_opioid_data_interpolated.csv", index=False)
